# %%
import sys
import os

# Add parent directory to path to import utils
sys.path.append(os.path.abspath(".."))

from utils.metrics import (
    calculate_metrics,
    evaluate_category,
    plot_performance_heatmap,
    plot_category_performance,
    create_tag_network,
    plot_tag_network
)

# %%
import sys
import os

# Add parent directory to path to import utils
sys.path.append(os.path.abspath(".."))

from utils.metrics import (
    calculate_metrics,
    evaluate_category,
    plot_performance_heatmap,
    plot_category_performance,
    create_tag_network,
    plot_tag_network
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 # Add parent directory to path to import utils
#       5 sys.path.append(os.path.abspath(".."))
# ----> 7 from utils.metrics import (
#       8     calculate_metrics,
#       9     evaluate_category,
#      10     plot_performance_heatmap,
#      11     plot_category_performance,
#      12     create_tag_network,
#      13     plot_tag_network
#      14 )
#
# File d:\Kings College\Dissertation\dissertation-code\utils\metrics.py:2
# ----> 2 from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\__init__.py:84
#      70     # We are not importing the rest of scikit-learn during the build
# ...

# %%
import os

# Set the environment variable
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'D:/Image testing/dissertation-422914-f468f25ddf8d.json'

# %%
import os

# Set the environment variable
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'D:/Image testing/dissertation-422914-f468f25ddf8d.json'

# %%
from google.cloud import vision
import os

def detect_labels(path, all_labels):
    """Detects labels in the file and adds them to the all_labels dictionary."""
    client = vision.ImageAnnotatorClient()

    with open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)
    response = client.label_detection(image=image)
    labels = response.label_annotations

    print(f'Labels for {os.path.basename(path)}:')
    label_descriptions = []
    for label in labels:
        print(label.description)
        label_descriptions.append(label.description)
    print()  # Add an empty line for better readability

    if response.error.message:
        raise Exception(f'{response.error.message}')

    # Add labels to the all_labels dictionary
    all_labels[os.path.basename(path)] = label_descriptions

def detect_labels_in_directory(directory_path):
    """Detects labels in all images in the directory and saves them to a single file."""
    all_labels = {}
    for filename in os.listdir(directory_path):
        if filename.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif')):
            image_path = os.path.join(directory_path, filename)
            detect_labels(image_path, all_labels)

    # Write all labels to a single text file
    labels_file_path = os.path.join(directory_path, 'people_vision_tags.txt')
    with open(labels_file_path, 'w') as label_file:
        for image, labels in all_labels.items():
            label_file.write(f'Labels for {image}:\n')
            label_file.write('\n'.join(labels))
            label_file.write('\n\n')

# Path to your directory containing images
directory_path = 'D:/Kings College/Dissertation/Revised Image Datasets/People'

# Detect labels in all images in the directory
detect_labels_in_directory(directory_path)
# Out:
# Labels for adults selfie.jpg:
# Smile
# Nose
# Skin
# Chin
# Mouth
# Facial expression
# Tooth
# White
# Human
# Neck
#
# Labels for baby_girl.jpg:
# Face
# Skin
# Arm
# White
# Product
# Baby & toddler clothing
# Sleeve
# Gesture
# Toddler
# Happy
#
# Labels for black girl.jpg:
# Forehead
# Nose
# Brown
# Cheek
# Skin
# Lip
# Eyelash
# Flash photography
# Jaw
# Temple
#
# Labels for black portrait.jpg:
# Forehead
# Nose
# Cheek
# Lip
# Eyelash
# Flash photography
# Jaw
# Iris
# Ear
# No expression
#
# Labels for elderly doing excercise.jpg:
# Furniture
# Gesture
# Happy
# Chair
# Couch
# Event
# Fashion design
# Performing arts
# Fun
# Leisure
#
# Labels for elderly gardening.jpg:
# Plant
# Plant community
# People in nature
# Sky
# Natural environment
# Tree
# Farmer
# Grass
# Agriculture
# Natural landscape
#
# Labels for elderly playing table tennis.jpg:
# Smile
# Muscle
# Gesture
# Happy
# Leisure
# T-shirt
# Community
# Shorts
# Grass
# Competition event
#
# ...
